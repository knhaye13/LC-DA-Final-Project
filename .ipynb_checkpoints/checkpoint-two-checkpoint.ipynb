# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset: Correlation between Posture & Personality Trait (kaggle.com)
#
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
#importing libraries and aliases for eda and visuals
import pandas as pd
import numpy as np
#visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# read in dataset and creating dataframe
df = pd.read_csv('Myers Briggs Table_S1 (1).csv')

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
# observing the top 5 rows and all columns
df.head()
# Out:
#    S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0     1   53      62     125  Female            Low     0.0     0.0     0.0
# 1     2   52      69     157    Male           High     7.0     8.0     5.0
# 2     3   30      69     200    Male           High     0.0     0.0     0.0
# 3     4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4     5   45      63     199  Female       Moderate     4.0     5.0     2.0
#
#    PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 0     0.0  ESFJ  18   3  17   9   9  13  18   4       A
# 1     3.0  ISTJ   6  15  14  12  21   3  13   9       B
# 2     0.0  ESTJ  15   6  16  10  15   9  12  10       A
# 3     1.5  ISTJ   6  15  21   5  13  11  19   3       D
# 4     2.0  ENFJ  14   7  20   6   9  15  16   6       A

# %%
# observing the last 5 rows
df.tail()
# Out:
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 92    93   16      58     100    Male       Moderate     0.0     0.0     0.0
# 93    94   45      62     134  Female       Moderate     0.0     4.0     0.0
# 94    95   43      69     188    Male       Moderate     2.0     0.0     0.0
# 95    96   28      67     180  Female            Low     0.0     0.0     0.0
# 96    97   43      69     188    Male       Moderate     4.0     0.0     0.0
#
#     PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 92     3.0  ESTP  19   2  22   4  19   5   2  20       B
# 93     0.0  ESFJ  11  10  17   9   6  18  13   9       B
# 94     0.0  ENFP  12   9   9  17   6  18   2  20       A
# 95     0.0  ESFJ  11  10  22  14   8  16  14   8       B
# 96     0.0  ENFP  12   9   9  17   6  18   2  20       A

# %%
#checking the data types
df.dtypes
# Out:
# S No                int64
# AGE                 int64
# HEIGHT              int64
# WEIGHT              int64
# SEX                object
# ACTIVITY LEVEL     object
# PAIN 1            float64
# PAIN 2            float64
# PAIN 3            float64
# PAIN 4            float64
# MBTI               object
# E                   int64
# I                   int64
# S                   int64
# N                   int64
# T                   int64
# F                   int64
# J                   int64
# P                   int64
# POSTURE            object
# dtype: object

# %%
# checking the full shape of the dataset
df.shape
# Out:
# (97, 20)

# %%
# returning a random sample to observe now that I know the data types and look at the column names
df.sample(10)
# Out:
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 30    31   46      66     222    Male            Low     0.0     0.0     0.0
# 48    49   20      68     155    Male            Low     1.0     4.0     1.0
# 15    16   62      71     165    Male            Low     0.0     1.0     0.0
# 53    54   19      68     113  Female            Low     0.0     4.0     6.0
# 64    65   42      70     170    Male            Low     0.0     4.0     0.0
# 65    66   18      62     110  Female            Low     4.0     5.0     0.0
# 90    91   29      65     125  Female       Moderate     2.0     0.0     0.0
# 52    53   50      65     172  Female            Low     0.0     0.0     0.0
# 71    72   45      67     148    Male            Low     2.0     3.0     0.0
# 5      6   68      74     182    Male            Low     0.0     2.5     1.5
#
#     PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 30     8.0  ESFP  18   3  14  12  12  12   2  20       A
# 48     2.0  ESTP  16   5  17   9  15   9  10  12       B
# 15     0.0  ISTJ   2  19  14  12  22   2  19   3       D
# 53     2.0  INFJ   7  14  18   8  12  12  14   8       D
# 64     0.0  ESFP  18   3  17   9   5  19   6  16       A
# 65     0.0  ISTJ   4  17  22   4  13  11  20   2       B
# 90     4.0  ENFP  19   2  13  13  12  12  10  12       A
# 52     3.0  ESFP  14   7  19   7   1  23   5  17       A
# 71     5.0  ISFJ   5  16  18   8  12  12  17   5       C
# 5      0.0  ISFP   4  17  17   9  11  13   4  18       D

# %%
# quick overview of the dataset for nulls
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S No            97 non-null     int64
#  1   AGE             97 non-null     int64
#  2   HEIGHT          97 non-null     int64
#  3   WEIGHT          97 non-null     int64
#  4   SEX             97 non-null     object
#  5   ACTIVITY LEVEL  97 non-null     object
#  6   PAIN 1          97 non-null     float64
#  7   PAIN 2          97 non-null     float64
#  8   PAIN 3          97 non-null     float64
#  9   PAIN 4          97 non-null     float64
#  10  MBTI            97 non-null     object
#  11  E               97 non-null     int64
#  12  I               97 non-null     int64
#  13  S               97 non-null     int64
#  14  N               97 non-null     int64
#  15  T               97 non-null     int64
#  16  F               97 non-null     int64
#  17  J               97 non-null     int64
#  18  P               97 non-null     int64
#  19  POSTURE         97 non-null     object
# dtypes: float64(4), int64(12), object(4)
# memory usage: 15.3+ KB

# %%
# observing #of unique elements in each column
df.nunique()
# Out:
# S No              97
# AGE               53
# HEIGHT            17
# WEIGHT            55
# SEX                2
# ACTIVITY LEVEL     3
# PAIN 1            15
# PAIN 2            17
# PAIN 3            15
# PAIN 4            17
# MBTI              15
# E                 20
# I                 20
# S                 20
# N                 20
# T                 23
# F                 23
# J                 21
# P                 21
# POSTURE            4
# dtype: int64

# %%
# Columns Legend
# AGE - Age of the candidate
# HEIGHT - Height of the candidate
# WEIGHT - Weight of the candidate
# SEX - Gender of the candidate
# ACTIVITY LEVEL - Daily activity of the candidate
# PAIN 1, PAIN 2, PAIN 3, PAIN 4 - Pain experienced at different places on a scale of 10
# MBTI - Myers Briggs Personality type
# E - Extrovertism
# I - Introvertism
# S - Sensing
# N - Intuition
# T - Thinking
# F - Feeling
# J - Judging
# P - Perceiving
# POSTURE - ideal posture (A), kyphosis-lordosis (B), flat back (C), sway-back (D

# %%
#renaming column names for better understanding
df = df.rename(columns={"PAIN 1":"Neck Pain", "PAIN 2":"Upper Back Pain","PAIN 3":"Lower Back Pain","PAIN 4":"Spine Base Pain","E":"Extrovert","Intuition":"Introvert","S":"Sensing","Introvert":"Intuition","T":"Thinking","F":"Feeling","J":"Judging","P":"Perceiving"})
df
#thiking of renaming posture column aslo, will circle back
# Out:
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  Neck Pain  \
# 0      1   53      62     125  Female            Low        0.0
# 1      2   52      69     157    Male           High        7.0
# 2      3   30      69     200    Male           High        0.0
# 3      4   51      66     175    Male       Moderate        9.5
# 4      5   45      63     199  Female       Moderate        4.0
# ..   ...  ...     ...     ...     ...            ...        ...
# 92    93   16      58     100    Male       Moderate        0.0
# 93    94   45      62     134  Female       Moderate        0.0
# 94    95   43      69     188    Male       Moderate        2.0
# 95    96   28      67     180  Female            Low        0.0
# 96    97   43      69     188    Male       Moderate        4.0
#
#     Upper Back Pain  Lower Back Pain  Spine Base Pain  MBTI  Extrovert  \
# 0               0.0              0.0              0.0  ESFJ         18
# 1               8.0              5.0              3.0  ISTJ          6
# 2               0.0              0.0              0.0  ESTJ         15
# 3               9.5              9.5              1.5  ISTJ          6
# 4               5.0              2.0              2.0  ENFJ         14
# ..              ...              ...              ...   ...        ...
# 92              0.0              0.0              3.0  ESTP         19
# 93              4.0              0.0              0.0  ESFJ         11
# 94              0.0              0.0              0.0  ENFP         12
# 95              0.0              0.0              0.0  ESFJ         11
# 96              0.0              0.0              0.0  ENFP         12
#
#     Intorvert  Sensing  Introvert  Thinking  Feeling  Judging  Perceiving  \
# 0           3       17          9         9       13       18           4
# 1          15       14         12        21        3       13           9
# 2           6       16         10        15        9       12          10
# 3          15       21          5        13       11       19           3
# 4           7       20          6         9       15       16           6
# ..        ...      ...        ...       ...      ...      ...         ...
# 92          2       22          4        19        5        2          20
# 93         10       17          9         6       18       13           9
# 94          9        9         17         6       18        2          20
# 95         10       22         14         8       16       14           8
# 96          9        9         17         6       18        2          20
#
#    POSTURE
# 0        A
# 1        B
# 2        A
# 3        D
# 4        A
# ..     ...
# 92       B
# 93       B
# 94       A
# 95       B
# 96       A
#
# [97 rows x 20 columns]

# %%
# checking value distributions for activity level, MBTI and Posture columns
df['ACTIVITY LEVEL'].value_counts()
# Out:
# Low         74
# Moderate    17
# High         6
# Name: ACTIVITY LEVEL, dtype: int64

# %%
df['MBTI'].value_counts()
# Out:
# ESFP    12
# ESFJ    11
# ESTP    10
# ENFP    10
# ESTJ     7
# ISFP     7
# ISTJ     6
# ENFJ     5
# ENTP     5
# ISFJ     5
# ENTJ     5
# INFP     5
# ISTP     4
# INFJ     4
# INTJ     1
# Name: MBTI, dtype: int64

# %%
df['POSTURE'].value_counts()
# Out:
# B    36
# A    22
# D    20
# C    19
# Name: POSTURE, dtype: int64

# %%
# checking nulls
df.isnull().sum()
# Out:
# S No              0
# AGE               0
# HEIGHT            0
# WEIGHT            0
# SEX               0
# ACTIVITY LEVEL    0
# PAIN 1            0
# PAIN 2            0
# PAIN 3            0
# PAIN 4            0
# MBTI              0
# E                 0
# I                 0
# S                 0
# N                 0
# T                 0
# F                 0
# J                 0
# P                 0
# POSTURE           0
# dtype: int64

# %%
# statistics for numerical columns
df.describe()
# Out:
#             S No        AGE     HEIGHT     WEIGHT     PAIN 1     PAIN 2  \
# count  97.000000  97.000000  97.000000   97.00000  97.000000  97.000000
# mean   49.000000  43.855670  65.731959  159.43299   2.139175   3.747423
# std    28.145456  16.776093   3.737522   36.19591   2.572635   3.191071
# min     1.000000  11.000000  58.000000   68.00000   0.000000   0.000000
# 25%    25.000000  30.000000  63.000000  135.00000   0.000000   0.000000
# 50%    49.000000  45.000000  66.000000  157.00000   1.000000   3.000000
# 75%    73.000000  56.000000  68.000000  183.00000   4.000000   7.000000
# max    97.000000  82.000000  74.000000  263.00000   9.500000  10.000000
#
#           PAIN 3     PAIN 4          E          I          S          N  \
# count  97.000000  97.000000  97.000000  97.000000  97.000000  97.000000
# mean    1.943299   2.530928  12.690722   8.288660  15.134021  11.041237
# std     2.587909   3.111483   5.717956   5.697146   4.833970   4.732242
# min     0.000000   0.000000   2.000000   0.000000   5.000000   1.000000
# 25%     0.000000   0.000000   8.000000   3.000000  12.000000   7.000000
# 50%     0.500000   0.000000  13.000000   8.000000  15.000000  11.000000
# 75%     3.500000   5.000000  18.000000  13.000000  19.000000  14.000000
# max    10.000000  10.000000  21.000000  19.000000  25.000000  21.000000
#
#                T          F          J          P
# count  97.000000  97.000000  97.000000  97.000000
# mean   10.505155  13.443299  10.319588  11.680412
# std     5.332924   5.297344   5.727395   5.711003
# min     0.000000   2.000000   0.000000   2.000000
# 25%     6.000000  10.000000   5.000000   6.000000
# 50%    11.000000  13.000000  11.000000  11.000000
# 75%    14.000000  18.000000  16.000000  17.000000
# max    22.000000  24.000000  20.000000  22.000000

# %%
#going back to look at all columns again, and observing non-numerical data types again.
df.head()
# Out:
#    S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0     1   53      62     125  Female            Low     0.0     0.0     0.0
# 1     2   52      69     157    Male           High     7.0     8.0     5.0
# 2     3   30      69     200    Male           High     0.0     0.0     0.0
# 3     4   51      66     175    Male       Moderate     9.5     9.5     9.5
# 4     5   45      63     199  Female       Moderate     4.0     5.0     2.0
#
#    PAIN 4  MBTI   E   I   S   N   T   F   J   P POSTURE
# 0     0.0  ESFJ  18   3  17   9   9  13  18   4       A
# 1     3.0  ISTJ   6  15  14  12  21   3  13   9       B
# 2     0.0  ESTJ  15   6  16  10  15   9  12  10       A
# 3     1.5  ISTJ   6  15  21   5  13  11  19   3       D
# 4     2.0  ENFJ  14   7  20   6   9  15  16   6       A

# %%
#I want to look more at the age column, and observe age rnages vs MBTI's
df.sort_values(by='AGE', inplace=True) #sorting the df by age
df.tail(20)
# Out:
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITY LEVEL  Neck Pain  \
# 16    17   59      66     138  Female            Low        6.0
# 68    69   60      68     222    Male            Low        0.5
# 10    11   61      67     210    Male            Low        5.0
# 38    39   61      63     155    Male            Low        3.5
# 6      7   62      68     263    Male            Low        7.0
# 55    56   62      61     150  Female            Low        2.0
# 15    16   62      71     165    Male            Low        0.0
# 20    21   63      66     185  Female            Low        8.0
# 46    47   63      62     150  Female            Low        2.0
# 21    22   64      69     176    Male            Low        0.5
# 7      8   65      61     143  Female            Low        0.0
# 35    36   66      63     142  Female            Low        2.0
# 8      9   66      67     180    Male            Low        0.5
# 45    46   66      66     184    Male            Low        4.0
# 5      6   68      74     182    Male            Low        0.0
# 23    24   71      61     140  Female            Low        8.0
# 22    23   71      68     156  Female            Low        2.0
# 78    79   75      63     143  Female            Low        4.0
# 44    45   80      59     115  Female            Low        0.0
# 42    43   82      60     159    Male            Low        0.0
#
#     Upper Back Pain  Lower Back Pain  Spine Base Pain  MBTI  Extrovert  \
# 16              3.0              6.0              6.0  ESTJ         12
# 68              0.5              0.5              2.5  ISTP          7
# 10              0.0              0.0              9.0  ENTP         11
# 38              3.5              3.5              6.0  ESTP         18
# 6              10.0             10.0             10.0  ISTP          7
# 55              2.0              2.0              2.0  ESTJ         17
# 15              1.0              0.0              0.0  ISTJ          2
# 20              0.0              3.0              7.0  INFP          2
# 46             10.0              0.0              4.0  ISFP          9
# 21              0.5              0.5              0.5  ESTP         13
# 7               9.0              5.0             10.0  ESTJ         17
# 35              0.0              0.0              0.0  ISTJ          4
# 8               3.5              0.5              9.5  ESFJ         19
# 45              3.0              0.0              0.0  ISTJ         10
# 5               2.5              1.5              0.0  ISFP          4
# 23              3.0              3.0              8.0  ESFJ         12
# 22              8.0              0.0              6.0  ESTP         13
# 78              6.0              4.0              6.0  ESTJ         12
# 44              0.0              0.0              0.0  ENFP         19
# 42              0.0              0.0              0.0  ESFP         21
#
#     Intorvert  Sensing  Introvert  Thinking  Feeling  Judging  Perceiving  \
# 16          9       18          8        14       10       20           2
# 68         14       19          7        15        9        3          19
# 10         10        6         20        16        8       10          12
# 38          3       23          3        15        9        6          16
# 6          14       20          6        14       10        9          13
# 55          4       20          6         8       16       16           6
# 15         19       14         12        22        2       19           3
# 20         19       10         16        10       14       11          11
# 46         12       20          6         0       24        4          18
# 21          8       25          1        18        6        8          14
# 7           4       17          9        19        5       17           5
# 35         17       16         10        17        7       18           4
# 8           2       18          8        11       13       13           9
# 45         11       18          8        21        3       14           8
# 5          17       17          9        11       13        4          18
# 23          9       23          3         5       19       16           6
# 22          8       15         11        16        8        7          15
# 78          9       17          9        13       11       16           6
# 44          2       11         15         6       18        3          19
# 42          0       20          6         6       18        2          20
#
#    POSTURE
# 16       A
# 68       C
# 10       B
# 38       B
# 6        B
# 55       B
# 15       D
# 20       D
# 46       D
# 21       B
# 7        D
# 35       C
# 8        C
# 45       D
# 5        D
# 23       D
# 22       B
# 78       B
# 44       A
# 42       A

# %%
#seperate the ages 0-18 and classify as dreamers
dreamer = df[df["AGE"] <=18]
dreamer[['AGE', 'MBTI', 'POSTURE']]
# Out:
#     AGE  MBTI POSTURE
# 85   11  ENFP       A
# 47   13  ENFJ       B
# 92   16  ESTP       B
# 91   16  ENFJ       B
# 82   16  INFP       D
# 40   17  INFP       C
# 49   18  INFJ       B
# 65   18  ISTJ       B

# %%
#seperate the ages 19-36 and classify as explorer
explorer = df[(df["AGE"] >=19) & (df["AGE"] <=36)]
explorer[['AGE', 'MBTI', 'POSTURE']]
# Out:
#     AGE  MBTI POSTURE
# 84   19  ENTJ       D
# 53   19  INFJ       D
# 32   20  ESTP       B
# 48   20  ESTP       B
# 57   20  ESFP       B
# 62   21  ESFP       B
# 88   22  ESFJ       B
# 18   23  ESFP       B
# 66   24  INTJ       C
# 61   25  ESTP       A
# 28   26  ENTJ       D
# 63   28  ENTP       C
# 95   28  ESFJ       B
# 87   28  ESFJ       B
# 90   29  ENFP       A
# 56   29  ESFP       B
# 2    30  ESTJ       A
# 70   30  ESFP       A
# 14   30  ESTP       A
# 11   33  ISFJ       B
# 17   33  ENFP       B
# 33   34  ENTJ       C
# 26   36  ESTP       A

# %%
#seperate the ages 37-54 and classify as builder
builder = df[(df["AGE"] >=37) & (df["AGE"] <=54)]
builder[['AGE', 'MBTI', 'POSTURE']]
# Out:
#     AGE  MBTI POSTURE
# 69   37  INFP       D
# 67   39  ENTP       B
# 83   39  ESFP       B
# 27   40  ISTP       D
# 25   41  ISFJ       C
# 60   42  ESFJ       B
# 36   42  ENFJ       C
# 64   42  ESFP       A
# 94   43  ENFP       A
# 58   43  ISFJ       C
# 59   43  ISTP       B
# 96   43  ENFP       A
# 29   43  ENFP       A
# 79   44  ENFP       B
# 71   45  ISFJ       C
# 77   45  ISFP       D
# 75   45  ISFJ       A
# 4    45  ENFJ       A
# 93   45  ESFJ       B
# 72   45  ENTJ       B
# 30   46  ESFP       A
# 54   47  ESFJ       B
# 31   47  ESTJ       D
# 43   48  ENFP       A
# 80   48  INFP       C
# 12   48  ESFJ       D
# 19   48  ISFP       C
# 39   49  ENFJ       B
# 74   49  ESTJ       B
# 81   49  ESFP       C
# 52   50  ESFP       A
# 24   50  INFJ       C
# 3    51  ISTJ       D
# 1    52  ISTJ       B
# 37   52  ENFP       A
# 73   53  ESFJ       C
# 0    53  ESFJ       A
# 34   54  ISFP       D

# %%
#seperate the ages 55-72 and classify as mentor
mentor = df[(df["AGE"] >=55) & (df["AGE"] <=72)]
mentor[['AGE', 'MBTI', 'POSTURE']]
# Out:
#     AGE  MBTI POSTURE
# 86   55  ENTP       A
# 76   55  ESTP       C
# 51   56  ENTP       B
# 50   56  ESFP       C
# 89   56  ISFP       C
# 41   57  ISFP       D
# 13   57  ENTJ       B
# 9    58  INFJ       D
# 16   59  ESTJ       A
# 68   60  ISTP       C
# 10   61  ENTP       B
# 38   61  ESTP       B
# 6    62  ISTP       B
# 55   62  ESTJ       B
# 15   62  ISTJ       D
# 46   63  ISFP       D
# 20   63  INFP       D
# 21   64  ESTP       B
# 7    65  ESTJ       D
# 35   66  ISTJ       C
# 8    66  ESFJ       C
# 45   66  ISTJ       D
# 5    68  ISFP       D
# 23   71  ESFJ       D
# 22   71  ESTP       B

# %%
#seperate the ages 73-90 and classify as giver
giver = df[(df["AGE"] >=73) & (df["AGE"] <=90)]
giver[['AGE', 'MBTI', 'POSTURE']]
# Out:
#     AGE  MBTI POSTURE
# 78   75  ESTJ       B
# 44   80  ENFP       A
# 42   82  ESFP       A

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
dreamer_1.plot(kind='line')
# Out:
# <Axes: >

# %%
Posture_df = df['POSTURE'].value_counts().index
sns.countplot(y='POSTURE', order=Posture_df, data=df)
# Out:
# <Axes: xlabel='count', ylabel='POSTURE'>

# %%
MBTI_df = df['MBTI'].value_counts().index
sns.countplot(y='MBTI', order=MBTI_df, data=df)
# Out:
# <Axes: xlabel='count', ylabel='MBTI'>

# %%
Extroverts = df[df['E'] > df['I']]
Introverts = df[df['I'] >= df['E']]
Sensing = df[df['S'] > df['N']]
Inituition = df[df['N'] >= df['S']]
Thinking = df[df['T'] > df['F']]
Feeling = df[df['F'] >= df['T']]

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset? There was no information regarding how Activity Levels were measured, I was surprised to see the majority as 'Low'.
# 2. Do you have any concerns about your dataset? No
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data? Make sure the 'MBTI' are assigned correctly.
